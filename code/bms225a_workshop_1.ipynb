# %% [markdown]
# <a href="https://colab.research.google.com/github/charlesrcrain/bms225a/blob/main/code/bms225a_workshop_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.12/dist-packages/pandas/__init__.py'>

# %%
print("chang liu is 98% monster")
print("gilbert herrera likes almonds")
# Out:
# chang liu is 98% monster
# gilbert herrera likes almonds

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and axes with increased resolution
fig, ax = plt.subplots(figsize=(19.2, 10.8), dpi=100) # 1080p is roughly 1920x1080 pixels, so we can set figsize to 19.2x10.8 inches and dpi to 100

# Draw the main body of the apple (a circle)
circle = plt.Circle((0, 0), 1, color='red')
ax.add_patch(circle)

# Draw a stem (a line)
ax.plot([0, 0.5], [1, 1.5], color='brown', linewidth=2)

# Draw a leaf (a simple ellipse or circle)
leaf = plt.Circle((0.6, 1.3), 0.2, color='green')
ax.add_patch(leaf)

# Set limits and aspect ratio
ax.set_xlim([-1.5, 1.5])
ax.set_ylim([-1.5, 2])
ax.set_aspect('equal', adjustable='box')

# Hide axes
ax.axis('off')

# Show the plot
plt.title("A Simple Apple")
plt.show()
