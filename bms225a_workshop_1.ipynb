# %% [markdown]
# <a href="https://colab.research.google.com/github/charlesrcrain/bms225a/blob/main/bms225a_workshop_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.12/dist-packages/pandas/__init__.py'>

# %%
for _ in range(1000):
  print("chang liu is 98% monster")
# Out:
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# chang liu is 98% monster
# ...
